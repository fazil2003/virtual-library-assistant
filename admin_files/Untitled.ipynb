# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("sales.csv")

# %%
df
# Out:
#     id  book_id  year  month keywords
# 0    1        1  2020      1   python
# 1    2        2  2020      1   python
# 2    3        3  2020      1     quiz
# 3    4        1  2020      1     quiz
# 4    5        2  2020      1     quiz
# 5    6        1  2020      1     quiz
# 6    7        3  2020      2   python
# 7    8        1  2020      2     quiz
# 8    9        3  2020      2     quiz
# 9   10        2  2020      2   python
# 10  11        1  2020      3     quiz
# 11  12        2  2020      3   python
# 12  13        3  2020      3   python
# 13  14        3  2020      3   python
# 14  15        2  2020      3     quiz

# %%
filters=df['year']==2020
df=df.loc[filters]

# %%
df
# Out:
#     id  book_id  year  month keywords
# 0    1        1  2020      1   python
# 1    2        2  2020      1   python
# 2    3        3  2020      1     quiz
# 3    4        1  2020      1     quiz
# 4    5        2  2020      1     quiz
# 5    6        1  2020      1     quiz
# 6    7        3  2020      2   python
# 7    8        1  2020      2     quiz
# 8    9        3  2020      2     quiz
# 9   10        2  2020      2   python
# 10  11        1  2020      3     quiz
# 11  12        2  2020      3   python
# 12  13        3  2020      3   python
# 13  14        3  2020      3   python
# 14  15        2  2020      3     quiz

# %%
results=df.loc[df['month'] == 2]
results
# Out:
#    id  book_id  year  month keywords
# 6   7        3  2020      2   python
# 7   8        1  2020      2     quiz
# 8   9        3  2020      2     quiz
# 9  10        2  2020      2   python

# %%
results
# Out:
#    id  book_id  year  month keywords
# 6   7        3  2020      2   python
# 7   8        1  2020      2     quiz
# 8   9        3  2020      2     quiz
# 9  10        2  2020      2   python

# %%
df=df.query("year == 2020 & keywords == 'quiz'")

# %%
df
# Out:
#     id  book_id  year  month keywords
# 2    3        3  2020      1     quiz
# 3    4        1  2020      1     quiz
# 4    5        2  2020      1     quiz
# 5    6        1  2020      1     quiz
# 7    8        1  2020      2     quiz
# 8    9        3  2020      2     quiz
# 10  11        1  2020      3     quiz
# 14  15        2  2020      3     quiz

# %%
# %matplotlib inline

# %%
df.plot(x ='year', y='month', kind = 'scatter')
# Out:
# <AxesSubplot:xlabel='year', ylabel='month'>

# %%
df['keywords'].str.count('quiz')
# Out:
# 0     0
# 1     0
# 2     1
# 3     1
# 4     1
# 5     1
# 6     0
# 7     1
# 8     1
# 9     0
# 10    1
# 11    0
# 12    0
# 13    0
# 14    1
# Name: keywords, dtype: int64

# %%
dfc=df

# %%
dfc
# Out:
#     id  book_id  year  month keywords
# 0    1        1  2020      1   python
# 1    2        2  2020      1   python
# 2    3        3  2020      1     quiz
# 3    4        1  2020      1     quiz
# 4    5        2  2020      1     quiz
# 5    6        1  2020      1     quiz
# 6    7        3  2020      2   python
# 7    8        1  2020      2     quiz
# 8    9        3  2020      2     quiz
# 9   10        2  2020      2   python
# 10  11        1  2020      3     quiz
# 11  12        2  2020      3   python
# 12  13        3  2020      3   python
# 13  14        3  2020      3   python
# 14  15        2  2020      3     quiz

# %%
y_axis=len(dfc.query("keywords=='python' & year==2020 & month==2"))
y_axis2=len(dfc.query("keywords=='quiz' & year==2020 & month==1"))

# %%
y_axis
# Out:
# 2

# %%
plt.plot([2,3],[2020,2080])
plt.ylabel("Year")
plt.show()

# %%
plt.bar(['python','quiz'],[1345,y_axis2])
# Out:
# <BarContainer object of 2 artists>
